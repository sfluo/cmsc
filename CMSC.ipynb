# %% [markdown]
# # CMSC Session Extraction

# %% [markdown]
# Comprehensive, Multi-Source Cybersecurity Events Dataset (https://csr.lanl.gov/data/cyber1/), also found https://www.secrepo.com)
#
# Explore temporal token Gram
#
# `$ gzip -dc auth.txt.gz | gsplit -l 50000000 -d - auth_part_ --filter='gzip > $FILE.csv.gz'`
#
# <b>Note: This notebook requires pandas 0.25.3 (python 3.6+) to run.</b>

# %%
import pandas as pd
cmsc_dataset = {
    "redteam": {
        'filename': './CMSC/redteam.txt.gz',
        'options': {'compression': 'gzip'},
        'columns': ['attack_time', 'src_user', 'src_machine', 'dst_machine']
    },

    "auth" : {
        'filename': './CMSC/auth_part_04.csv.gz',
        'options': {'compression': 'gzip'},
        'columns': ['time', 'src_user', 'dst_user', 'src_machine', 'dst_machine', 
                    'auth_type', 'logon_type', 'orientation', 'result']
    },
    
    "auth_100k" : {
        'filename': './CMSC/auth_100k.txt',
        'options': {},
        'columns': ['time', 'src_user', 'dst_user', 'src_machine', 'dst_machine', 
                    'auth_type', 'logon_type', 'orentiation', 'result']
    },

    "proc" : {
        'filename' :  './CMSC/proc.txt.gz',
        'options': {'compression': 'gzip'},
        'columns' : ["time","user_domain","computer","process" "name","action"]
    }
}

def load_logs(name):
    try:
        dataset =  cmsc_dataset[name]
        return pd.read_csv(dataset['filename'], **dataset['options'], header=None, names=dataset['columns'])
    except KeyError:
        print("Dataset [{}] does not exist".format(name))

# %%
load_logs('noexists')
# Out:
# Dataset [noexists] does not exist

# %% [markdown]
# ## Load Authentication Logs

# %%
auth = load_logs('auth')

# %%
auth = auth[(auth['orentiation'] == 'LogOn') | (auth['orientation'] == 'LogOff')]

# %%
auth.head(5)
# Out:
#       time     src_user     dst_user src_machine dst_machine auth_type  \
# 0  1044281   C609$@DOM1   C609$@DOM1        C609        C528  Kerberos
# 1  1044281   C612$@DOM1   C612$@DOM1        C612        C612         ?
# 2  1044281   C612$@DOM1   C612$@DOM1        C612        C612  Kerberos
# 3  1044281  C6312$@DOM1  C6312$@DOM1       C6312        C612  Kerberos
# 4  1044281   C664$@DOM1   C664$@DOM1        C612        C612         ?
#
#   logon_type orentiation   result
# 0    Network       LogOn  Success
# 1    Network      LogOff  Success
# 2    Network       LogOn  Success
# 3    Network       LogOn  Success
# 4    Network      LogOff  Success

# %% [markdown]
# ### Extract Sessions by LogOn and LogOff event
# - Use destination user and destination machine as key to find out all sessions with Logon and LogOff
# - Later we will look at processes created by each user on the destination machines as the events within a session

# %%
from enum import Enum

class State(Enum):
    Init = 0
    Started = 1
    Ended = 2

def isEnd(t):
    return t[0] == 0

def isStart(t):
    return t[1] == 0

"""
Suppress Event(a, b), start event if b == 0 else End event
"""
def suppress(events):
    output = []
    state = State.Init
    open_session = (0, 0)
    for e in events:
        
        if state == State.Init:
            if isEnd(e):
                open_session = (0, e[1])
            else:
                state = State.Started
                open_session = (e[0], 0)
                
        elif state == State.Started:
            if open_session[1] > 0:  
                output.append(open_session)
            
            if isEnd(e):
                open_session = (open_session[0], e[1])
                state = State.Ended
                
        else: 
            if isEnd(e):
                open_session = (open_session[0], e[1])  
            elif isStart(e):
                output.append(open_session)
                open_session = e
                state = State.Started
                
    if open_session[1] > 0 or open_session[0] > 0:
        output.append(open_session)
        
    return output

assert suppress([(71, 0), (81, 0), (0, 84), (0, 85)]) == [(71, 85)]
assert suppress([(71, 0), (81, 0), (0, 84)]) == [(71, 84)]
assert suppress([(71, 0), (81, 0)]) == [(71, 0)]
assert suppress([(0, 81)]) == [(0, 81)]

# %% [markdown]
# ### Convert LogOn/LogOff field to a tuple (_, _)
# - LogOn will be (_, 0) and logOff will be (0, _)

# %%
auth_sess = auth[(auth['orentiation'] == 'LogOn') | (auth['orentiation'] == 'LogOff')].assign(
    auth_time=auth.apply(lambda x: (x['time'], 0) if x['orentiation'] == 'LogOn' else (0, x['time']), axis=1),
).groupby(['dst_user', 'src_machine', 'dst_machine']).agg({'auth_time': lambda x: list(x)})

# %%
auth_sess.head(10)
# Out:
#                                                                                      auth_time
# dst_user            src_machine dst_machine
# ANONYMOUS LOGON@C1  C1          C1                                              [(1067590, 0)]
# ANONYMOUS LOGON@C10 C10         C10          [(0, 1066242), (0, 1066253), (0, 1067934), (0,...
#                     C10037      C10                                             [(1252299, 0)]
#                     C10144      C10                                             [(1252416, 0)]
#                     C10328      C10                               [(1252274, 0), (1252278, 0)]
#                     C11082      C10                                             [(1252789, 0)]
#                     C11303      C10                               [(1240219, 0), (1240221, 0)]
#                     C13107      C10                                             [(1252564, 0)]
#                     C13214      C10                                             [(1252542, 0)]
#                     C14005      C10                                             [(1088608, 0)]

# %% [markdown]
# ### identify sessions and remove open session (0, 0) or (0, _) if any

# %%
sessions = auth_sess.assign(
    sessions=auth_sess['auth_time'].apply(
        lambda x: [a for a in suppress(x) if a[0] != 0 and a[1] != 0]   # remove open session
    )
).reset_index()

# %%
# filter out empty user and open-sessions
auth_sessions = sessions[
    (sessions['dst_user'] != '') & (sessions['sessions'].apply(lambda x: len(x) != 0))
][['dst_user', 'src_machine', 'dst_machine', 'sessions']]

# %%
auth_sessions.head(25)
# Out:
#                     dst_user src_machine dst_machine  \
# 46      ANONYMOUS LOGON@C100        C100        C100
# 48     ANONYMOUS LOGON@C1000       C1000       C1000
# 87    ANONYMOUS LOGON@C10071      C10071      C10071
# 95    ANONYMOUS LOGON@C10089      C10089      C10089
# 102   ANONYMOUS LOGON@C10107      C10107      C10107
# 106   ANONYMOUS LOGON@C10114      C10114      C10114
# 109   ANONYMOUS LOGON@C10118      C10118      C10118
# 118   ANONYMOUS LOGON@C10136      C10136      C10136
# 124    ANONYMOUS LOGON@C1015       C1015       C1015
# 137   ANONYMOUS LOGON@C10150      C10150      C10150
# 173   ANONYMOUS LOGON@C10239      C10239      C10239
# 211   ANONYMOUS LOGON@C10331      C10331      C10331
# 221   ANONYMOUS LOGON@C10357      C10357      C10357
# 240   ANONYMOUS LOGON@C10388      C10388      C10388
# 257   ANONYMOUS LOGON@C10415      C10415      C10415
# 276    ANONYMOUS LOGON@C1046       C1046       C1046
# 307   ANONYMOUS LOGON@C10521      C10521      C10521
# 320   ANONYMOUS LOGON@C10552      C10552      C10552
# 324   ANONYMOUS LOGON@C10561      C10561      C10561
# 340   ANONYMOUS LOGON@C10589      C10589      C10589
# 344   ANONYMOUS LOGON@C10595      C10595      C10595
# 367   ANONYMOUS LOGON@C10638      C10638      C10638
# 2749  ANONYMOUS LOGON@C10675      C10675      C10675
# 2759  ANONYMOUS LOGON@C10694      C10694      C10694
# 2766  ANONYMOUS LOGON@C10701      C10701      C10701
#
#                                                sessions
# 46                                 [(1168334, 1228174)]
# 48                                 [(1064333, 1197942)]
# 87                                 [(1233821, 1246194)]
# 95                                 [(1233699, 1251215)]
# 102                                [(1063702, 1246756)]
# 106   [(1064084, 1088312), (1151129, 1151869), (1157...
# 109                                [(1062473, 1069278)]
# 118                                [(1233671, 1247378)]
# 124                                [(1134274, 1251502)]
# 137                                [(1077307, 1181568)]
# 173   [(1074052, 1090991), (1151061, 1170960), (1236...
# 211                                [(1063188, 1063193)]
# 221                                [(1064004, 1071074)]
# 240                                [(1065969, 1094831)]
# 257                                [(1063051, 1073065)]
# 276                                [(1177629, 1232732)]
# 307                                [(1233611, 1242847)]
# 320                                [(1064165, 1069703)]
# 324            [(1064741, 1183929), (1233736, 1251207)]
# 340   [(1159145, 1159812), (1160495, 1161643), (1243...
# 344                                [(1151084, 1245868)]
# 367                                [(1063347, 1241791)]
# 2749                               [(1234867, 1251869)]
# 2759           [(1153278, 1155629), (1160219, 1161448)]
# 2766                               [(1233187, 1251167)]

# %% [markdown]
# ## Load Redteam Logs

# %%
redteam = load_logs('redteam')
redteam['label'] = '1'

# %%
redteam.groupby('src_user').agg({'dst_machine': 'count'}).reset_index().sort_values(by='dst_machine').tail(10)
# Out:
#        src_user  dst_machine
# 102  U9947@DOM1           15
# 48   U3635@DOM1           18
# 23   U1723@DOM1           19
# 98   U8946@DOM1           19
# 79    U748@DOM1           26
# 37    U293@DOM1           31
# 22   U1653@DOM1           31
# 77    U737@DOM1           32
# 38   U3005@DOM1           36
# 70     U66@DOM1          118

# %%
redteam.tail(100)
# Out:
#      attack_time    src_user src_machine dst_machine label
# 649      1244695   U114@DOM1      C17693       C1710     1
# 650      1245222  U1106@DOM1      C17693       C4554     1
# 651      1245398  U1106@DOM1      C17693      C21919     1
# 652      1245678  U3575@DOM1      C17693       C5030     1
# 653      1246243  U3206@DOM1      C17693       C8585     1
# ..           ...         ...         ...         ...   ...
# 744      2552687   U655@DOM1      C17693        C828     1
# 745      2552687   U655@DOM1      C17693        C828     1
# 746      2552687   U655@DOM1      C17693        C828     1
# 747      2552687   U655@DOM1      C17693        C828     1
# 748      2557047   U737@DOM1      C19932        C108     1
#
# [100 rows x 5 columns]

# %%
labeled_auth = auth.join(redteam.set_index(['src_user', 'src_machine', 'dst_machine', 'attack_time']), 
                         on=['dst_user', 'src_machine', 'dst_machine', 'time'])

# %%
labeled_auth.head(10)
# Out:
#       time     src_user     dst_user src_machine dst_machine auth_type  \
# 0  1044281   C609$@DOM1   C609$@DOM1        C609        C528  Kerberos
# 1  1044281   C612$@DOM1   C612$@DOM1        C612        C612         ?
# 2  1044281   C612$@DOM1   C612$@DOM1        C612        C612  Kerberos
# 3  1044281  C6312$@DOM1  C6312$@DOM1       C6312        C612  Kerberos
# 4  1044281   C664$@DOM1   C664$@DOM1        C612        C612         ?
# 5  1044281  C6828$@DOM1  C6828$@DOM1       C6828        C528  Kerberos
# 6  1044281  C6897$@DOM1  C6897$@DOM1       C1015       C1015         ?
# 7  1044281   C729$@DOM1   C729$@DOM1       C1015       C1015         ?
# 8  1044281   C743$@DOM1   C743$@DOM1        C586        C586         ?
# 9  1044281   C743$@DOM1   C743$@DOM1        C743        C586  Kerberos
#
#   logon_type orentiation   result label
# 0    Network       LogOn  Success   NaN
# 1    Network      LogOff  Success   NaN
# 2    Network       LogOn  Success   NaN
# 3    Network       LogOn  Success   NaN
# 4    Network      LogOff  Success   NaN
# 5    Network       LogOn  Success   NaN
# 6    Network      LogOff  Success   NaN
# 7    Network      LogOff  Success   NaN
# 8    Network      LogOff  Success   NaN
# 9    Network       LogOn  Success   NaN

# %%
labeled_auth.label.fillna(0)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 49999995    0
# 49999996    0
# 49999997    0
# 49999998    0
# 49999999    0
# Name: label, Length: 42599254, dtype: object

# %%
labeled_auth[labeled_auth['label'] == '1']
# Out:
#              time    src_user    dst_user src_machine dst_machine auth_type  \
# 4179730   1066394    U66@DOM1    U66@DOM1      C17693       C3610      NTLM
# 4289405   1066725    U66@DOM1    U66@DOM1      C17693        C881      NTLM
# 4292560   1066734    U66@DOM1    U66@DOM1      C17693       C1482      NTLM
# 4309577   1066786    U66@DOM1    U66@DOM1      C17693       C2388      NTLM
# 4836042   1068312    U12@DOM1    U12@DOM1      C17693        C366      NTLM
# ...           ...         ...         ...         ...         ...       ...
# 48253180  1246653   U114@DOM1   U114@DOM1      C17693       C1710      NTLM
# 49450524  1251013  U3549@DOM1  U3549@DOM1      C17693       C1887      NTLM
# 49456293  1251033  U3549@DOM1  U3549@DOM1      C17693       C1887      NTLM
# 49465247  1251067  U3549@DOM1  U3549@DOM1      C17693        C586      NTLM
# 49595878  1251573  U3549@DOM1  U3549@DOM1      C17693        C457      NTLM
#
#          logon_type orentiation   result label
# 4179730     Network       LogOn  Success     1
# 4289405     Network       LogOn  Success     1
# 4292560     Network       LogOn  Success     1
# 4309577     Network       LogOn  Success     1
# 4836042     Network       LogOn  Success     1
# ...             ...         ...      ...   ...
# 48253180    Network       LogOn  Success     1
# 49450524    Network       LogOn  Success     1
# 49456293    Network       LogOn  Success     1
# 49465247    Network       LogOn  Success     1
# 49595878    Network       LogOn  Success     1
#
# [320 rows x 10 columns]

# %%
redteam_sessions = redteam.groupby(['src_user', 'src_machine', 'dst_machine']).agg(lambda x: list(x)).reset_index()

# %%
redteam_sessions.head(5)
# Out:
#        src_user src_machine dst_machine                         time
# 0    U1025@DOM1      C17693       C1046  [1153024, 1153118, 1153716]
# 1    U1025@DOM1      C17693        C338           [1152460, 1152644]
# 2    U1025@DOM1      C17693       C3597                    [1155729]
# 3  U10379@C3521      C17693       C3521            [726137, 2303788]
# 4    U1048@DOM1      C17693      C12320            [768006, 2305762]

# %%
auth_redteam = auth_sessions.join(redteam_sessions.set_index(['src_user', 'src_machine', 'dst_machine']), 
                                  on=['dst_user', 'src_machine', 'dst_machine'], 
                                  how='outer')

# %%
auth_sessions.head(10)
# Out:
#                    dst_user                src_user src_machine dst_machine  \
# 46     ANONYMOUS LOGON@C100    ANONYMOUS LOGON@C100        C100        C100
# 48    ANONYMOUS LOGON@C1000   ANONYMOUS LOGON@C1000       C1000       C1000
# 87   ANONYMOUS LOGON@C10071  ANONYMOUS LOGON@C10071      C10071      C10071
# 95   ANONYMOUS LOGON@C10089  ANONYMOUS LOGON@C10089      C10089      C10089
# 102  ANONYMOUS LOGON@C10107  ANONYMOUS LOGON@C10107      C10107      C10107
# 106  ANONYMOUS LOGON@C10114  ANONYMOUS LOGON@C10114      C10114      C10114
# 109  ANONYMOUS LOGON@C10118  ANONYMOUS LOGON@C10118      C10118      C10118
# 118  ANONYMOUS LOGON@C10136  ANONYMOUS LOGON@C10136      C10136      C10136
# 124   ANONYMOUS LOGON@C1015   ANONYMOUS LOGON@C1015       C1015       C1015
# 137  ANONYMOUS LOGON@C10150  ANONYMOUS LOGON@C10150      C10150      C10150
#
#                                               sessions
# 46                                [(1168334, 1228174)]
# 48                                [(1064333, 1197942)]
# 87                                [(1233821, 1246194)]
# 95                                [(1233699, 1251215)]
# 102                               [(1063702, 1246756)]
# 106  [(1064084, 1088312), (1151129, 1151869), (1157...
# 109                               [(1062473, 1069278)]
# 118                               [(1233671, 1247378)]
# 124                               [(1134274, 1251502)]
# 137                               [(1077307, 1181568)]

# %%
auth_redteam.head(10)
# Out:
#                    dst_user                src_user src_machine dst_machine  \
# 46     ANONYMOUS LOGON@C100    ANONYMOUS LOGON@C100        C100        C100
# 48    ANONYMOUS LOGON@C1000   ANONYMOUS LOGON@C1000       C1000       C1000
# 87   ANONYMOUS LOGON@C10071  ANONYMOUS LOGON@C10071      C10071      C10071
# 95   ANONYMOUS LOGON@C10089  ANONYMOUS LOGON@C10089      C10089      C10089
# 102  ANONYMOUS LOGON@C10107  ANONYMOUS LOGON@C10107      C10107      C10107
# 106  ANONYMOUS LOGON@C10114  ANONYMOUS LOGON@C10114      C10114      C10114
# 109  ANONYMOUS LOGON@C10118  ANONYMOUS LOGON@C10118      C10118      C10118
# 118  ANONYMOUS LOGON@C10136  ANONYMOUS LOGON@C10136      C10136      C10136
# 124   ANONYMOUS LOGON@C1015   ANONYMOUS LOGON@C1015       C1015       C1015
# 137  ANONYMOUS LOGON@C10150  ANONYMOUS LOGON@C10150      C10150      C10150
#
#                                               sessions time
# 46                                [(1168334, 1228174)]  NaN
# 48                                [(1064333, 1197942)]  NaN
# 87                                [(1233821, 1246194)]  NaN
# 95                                [(1233699, 1251215)]  NaN
# 102                               [(1063702, 1246756)]  NaN
# 106  [(1064084, 1088312), (1151129, 1151869), (1157...  NaN
# 109                               [(1062473, 1069278)]  NaN
# 118                               [(1233671, 1247378)]  NaN
# 124                               [(1134274, 1251502)]  NaN
# 137                               [(1077307, 1181568)]  NaN

# %% [markdown]
# # Load Proc Logs

# %%
procs = load_logs('proc')

# %%
procs.head(10)
# Out:
#    time  user_domain computer processname action
# 0     1     C1$@DOM1       C1         P16  Start
# 1     1  C1001$@DOM1    C1001          P4  Start
# 2     1  C1002$@DOM1    C1002          P4  Start
# 3     1  C1004$@DOM1    C1004          P4  Start
# 4     1  C1017$@DOM1    C1017          P4  Start
# 5     1  C1018$@DOM1    C1018          P4  Start
# 6     1  C1020$@DOM1    C1020          P3  Start
# 7     1  C1020$@DOM1    C1020          P4  Start
# 8     1  C1028$@DOM1    C1028         P16    End
# 9     1  C1029$@DOM1    C1029          P4  Start

# %%
procs['action'].unique()
# Out:
# array(['Start', 'End'], dtype=object)

# %%
allprocessnames = procs['processname'].unique()

# %%
len(allprocessnames)
# Out:
# 62974

# %%
procs.groupBy(['user_domain', 'computer', 'processname']).agg()

# %%
testprocs = procs.head(10000)

# %%
def identifyProcess(proc_df):
    proc_action_time = proc_df[(proc_df['action']=='Start') | (proc_df['action']=='End')].assign(
        action_time=proc_df.apply(lambda x: (x['time'], 0) if x['action'] == 'Start' else (0, x['time']), axis=1)
    ).groupby(['user_domain', 'computer', 'processname']).agg({'action_time': lambda x: list(x)})
    
    print(proc_action_time.head(2))
    proc_clean_df = proc_action_time.assign(
        proc_dur=proc_action_time['action_time'].apply(
            lambda x: [a for a in suppress(x) if a[0] != 0 and a[1] != 0]
        )
    ).reset_index()
    
    return proc_clean_df[proc_clean_df['proc_dur'].apply(lambda x: len(x) != 0)]

# %%
testprocs[testprocs['computer'] == 'C1006']
# Out:
#       time  user_domain computer processname action
# 448      2  C1006$@DOM1    C1006         P25  Start
# 1949     3  C1006$@DOM1    C1006         P25    End
# 3529     3     U20@DOM1    C1006         P20  Start
# 3531     3     U40@DOM1    C1006         P21  Start
# 3532     3     U40@DOM1    C1006        P259    End
# 3533     3     U40@DOM1    C1006        P259  Start
# 3534     3     U40@DOM1    C1006         P35  Start
# 4300     4     U40@DOM1    C1006         P21    End
# 4301     4     U40@DOM1    C1006         P35    End
# 5753    36  C1006$@DOM1    C1006         P25  Start
# 5786    37  C1006$@DOM1    C1006         P25    End
# 5787    37  C1006$@DOM1    C1006         P25  Start
# 5824    38  C1006$@DOM1    C1006         P25    End
# 5825    38  C1006$@DOM1    C1006         P25  Start
# 7037    67     U20@DOM1    C1006         P20    End
# 8078    96  C1006$@DOM1    C1006         P25  Start
# 8102    97  C1006$@DOM1    C1006         P25    End
# 8103    97  C1006$@DOM1    C1006         P25  Start

# %%
x=identifyProcess(testprocs)
# Out:
#                                           action_time
# user_domain computer processname
# C1$@DOM1    C1       P16             [(1, 0), (0, 6)]
# C10$@DOM1   C10      P9           [(44, 0), (0, 122)]

# %%
x[x['computer'] == 'C1006']
# Out:
#       user_domain computer processname  \
# 0        C1$@DOM1       C1         P16
# 1       C10$@DOM1      C10          P9
# 22    C1006$@DOM1    C1006         P25
# 23    C1007$@DOM1    C1007         P47
# 30     C101$@DOM1     C101         P25
# ...           ...      ...         ...
# 6875     U90@DOM1    C1786         P79
# 6877     U92@DOM1     C730         P53
# 6878     U92@DOM1     C730         P80
# 6879     U95@DOM1    C2055        P105
# 6880     U95@DOM1    C2055        P294
#
#                                             action_time  \
# 0                                      [(1, 0), (0, 6)]
# 1                                   [(44, 0), (0, 122)]
# 22    [(2, 0), (0, 3), (36, 0), (0, 37), (37, 0), (0...
# 23                                   [(21, 0), (0, 29)]
# 30    [(0, 12), (0, 17), (17, 0), (60, 0), (0, 72), ...
# ...                                                 ...
# 6875                 [(0, 9), (9, 0), (0, 67), (67, 0)]
# 6877                                   [(7, 0), (0, 9)]
# 6878                                   [(1, 0), (0, 7)]
# 6879  [(48, 0), (0, 62), (78, 0), (0, 111), (134, 0)...
# 6880                                 [(57, 0), (0, 62)]
#
#                                              proc_dur
# 0                                            [(1, 6)]
# 1                                         [(44, 122)]
# 22             [(2, 3), (36, 37), (37, 38), (38, 97)]
# 23                                         [(21, 29)]
# 30    [(17, 102), (102, 136), (136, 137), (137, 145)]
# ...                                               ...
# 6875                                        [(9, 67)]
# 6877                                         [(7, 9)]
# 6878                                         [(1, 7)]
# 6879                [(48, 62), (78, 111), (134, 143)]
# 6880                                       [(57, 62)]
#
# [645 rows x 5 columns]

# %%
t = x.groupby(['user_domain', 'computer']).apply(
    lambda x: list(zip(x['processname'], x['proc_dur']))).reset_index()

# %%
t[t['computer'] == 'C1006']
# Out:
#      user_domain computer                                                0
# 2    C1006$@DOM1    C1006  [(P25, [(2, 3), (36, 37), (37, 38), (38, 97)])]
# 368     U20@DOM1    C1006                               [(P20, [(3, 67)])]
# 389     U40@DOM1    C1006               [(P21, [(3, 4)]), (P35, [(3, 4)])]
